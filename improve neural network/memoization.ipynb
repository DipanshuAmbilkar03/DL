# %%
import time

# %%
def fibo(n) :
  if n == 1:
    return 1

  if n == 0:
    return 0

  return fibo(n-1) + fibo(n-2);

# %%
start = time.time()
print(fibo(10))
end = time.time()
print(end-start)
# Out:
# 55
# 0.00016951560974121094
