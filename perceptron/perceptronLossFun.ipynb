# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=15)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
import numpy as np 
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
levels = np.unique(y)
plt.scatter(X[:,0], X[:,1],
            c=y,                  
            cmap='tab10',         
            s=100)

from matplotlib.lines import Line2D
legend_handles = [Line2D([0], [0], marker='o', color='w',
                         markerfacecolor=plt.get_cmap('tab10')(i), markersize=10)
                  for i in levels]
plt.legend(legend_handles, levels, title='Classes')

plt.show()

# %%
# def perceptron(X,y) : 
#     w1=w2=b=1
#     learningRate = 0.1
#     epochs = 1000 
    
#     for j in range(epochs) :
#         for i in range(X.shape[0]) :
#             z = w1*X[i][0] + w2*X[i][1] + b

#             if z*y[i] < 0 :
#                 w1 = w1 + learningRate*y[i]*X[i][0]
#                 w2 = w2 + learningRate*y[i]*X[i][1]
#                 b = b + learningRate*y[i]
#     return w1,w2,b

# %%
def perceptron(X, y):
    w1 = w2 = b = 1.0
    lr = 0.1
    epochs = 1000

    for _ in range(epochs):
        errors = 0
        for i in range(X.shape[0]):
            z = w1*X[i][0] + w2*X[i][1] + b
            if z * y[i] <= 0:
                w1 += lr * y[i] * X[i][0]
                w2 += lr * y[i] * X[i][1]
                b  += lr * y[i]
                errors += 1
        if errors == 0:
            break

    return w1, w2, b

# %%
w1,w2,b = perceptron(X,y)

# %%
w1
# Out:
# np.float64(1.006638570722407)

# %%
w2
# Out:
# np.float64(0.22215119727529098)

# %%
b
# Out:
# np.float64(1.3000000000000003)

# %%
m = -(w1/w2)
c = -(b/w2)

# %%
print(m,c)
# Out:
# -4.531321834268464 -5.851870329508209

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + c

plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='tab10',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
