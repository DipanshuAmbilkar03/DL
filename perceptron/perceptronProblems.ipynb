# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xOr_data = pd.DataFrame()

# %%
or_data['x1'] = [1,1,0,0]
or_data['x2'] = [1,0,1,0]
or_data['y'] = [1,1,1,0]

# %%
and_data['x1'] = [1,1,0,0]
and_data['x2'] = [1,0,1,0]
and_data['y'] = [1,0,0,0]

# %%
xOr_data['x1'] = [1,1,0,0]
xOr_data['x2'] = [1,0,1,0]
xOr_data['y'] = [0,1,1,0]

# %%
and_data
# Out:
#    x1  x2  y
# 0   1   1  1
# 1   1   0  0
# 2   0   1  0
# 3   0   0  0

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x='x1',y='x2',hue='y',data=and_data)
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
xOr_data
# Out:
#    x1  x2  y
# 0   1   1  0
# 1   1   0  1
# 2   0   1  1
# 3   0   0  0

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x='x1',y='x2',hue='y',data=xOr_data)
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
or_data
# Out:
#    x1  x2  y
# 0   1   1  1
# 1   1   0  1
# 2   0   1  1
# 3   0   0  0

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x='x1',y='x2',hue='y',data=or_data)
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
from sklearn.linear_model import Perceptron

# %%
clf1 = Perceptron()
clf2 = Perceptron()
clf3 = Perceptron()

# %%
clf1.fit(and_data.iloc[:,:2].values,and_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf2.fit(or_data.iloc[:,:2].values,or_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf3.fit(xOr_data.iloc[:,:2].values,xOr_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-2.])

# %%
clf2.coef_
# Out:
# array([[2., 2.]])

# %%
clf2.intercept_
# Out:
# array([-1.])

# %%
clf3.coef_
# Out:
# array([[0., 0.]])

# %%
clf3.intercept_
# Out:
# array([0.])

# %%
x1 = np.linspace(-1,1,5)
y1 = -x1+1
plt.figure(figsize=(4,3))
plt.plot(x1,y1)
sns.scatterplot(x='x1',y='x2',hue='y',data=and_data)
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
x2 = np.linspace(-1,1,5)
y2 = -x2+0.5
plt.figure(figsize=(4,3))
plt.plot(x2,y2)
sns.scatterplot(x='x1',y='x2',hue='y',data=or_data)
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
# !pip install mlxtend

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(xOr_data.iloc[:,:2].values,xOr_data.iloc[:,-1].values,clf=clf3,legend=2)
plt.title("Non linear dataset for perceptron can't make a linear line")
# Out:
# Text(0.5, 1.0, "Non linear dataset for perceptron can't make a linear line")
